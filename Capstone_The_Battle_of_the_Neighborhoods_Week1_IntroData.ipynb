# %% [markdown]
# ## Capstone Project-The Battle of the Neighborhoods (Week 1)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# With the COVID-19 pandemic, many businesses like offices, schools, colleges, etc. have been shut down forcing people to work/study from home. However, the food industry personnel do not have the opportunity to work from home and are required to continue with their daily work activities while adhering to the safety measures.
#
# What’s concerning is that it can survive on different surfaces for quite a long time and once we come in contact with a contaminated surface, we can get infected too. This naturally makes us think twice before ordering food online or before visiting a restaurant to dine-in.
#
# This would also change consumer behavior and would affect our decision while choosing any food outlet. Consumers would not only look at food outlets that serve good quality food at a good price but will also look at the hygiene rating and the area in which the food outlet is located in to ensure that safety and hygiene are not being compromised.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# The aim of this project is to cluster the food outlets in San Francisco, California based on:
#
# 1. Customer Rating
# 2. Inspection Score
# 3. Location
# 4. Coronavirus cases in the neighborhood
# 5. Online Delivery Service
#
# Based on definition of our problem, factors that will influence our decission are:
# * Health Aspects of food outlet looking at Location Scores and Cornavirus cases.
# * Number of existing restaurants in the neighborhood (any type of restaurant)
# * Number of and distance to Italian restaurants in the neighborhood, if any
#
# We will be using data from the San Francisco Government API for Covid-19 and Health Inspection Data and the Foursquare API:
#
# - [San Francisco Neighborhood Covid-19 Data](#Covid_Data) - To get all the confirmed coronavirus cases in the different neighborhoods of San Francisco
#
# - [San Francisco Government Restaurant Health Inspection Data](#SF_Data) - Using the San Francisco's LIVES restaurant inspection data leverages the LIVES Flattened Schema (https://goo.gl/c3nNvr), which is based on LIVES version 2.0, cited on Yelp's website (http://www.yelp.com/healthscores).
#
# - [FourSquare API](#FourSquare) - Use the location coordinates of the districts we received from the Covid19 API and pass it as input to the FourSqaure API to retrieve 100 venues within 4 kms for each Neighborhood of San Francisco.

# %%
import warnings
warnings. filterwarnings("ignore")

# %%
#Install Libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

from pandas.io.json import json_normalize
import requests
import json

# !pip install geopy
from geopy.geocoders import Nominatim
from sklearn.cluster import KMeans
# !pip install folium
import folium
print("Libraries imported!")
# Out:
# Requirement already satisfied: geopy in c:\users\jdaggett\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\jdaggett\anaconda3\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: folium in c:\users\jdaggett\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: requests in c:\users\jdaggett\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: numpy in c:\users\jdaggett\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\jdaggett\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\jdaggett\anaconda3\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\jdaggett\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jdaggett\anaconda3\lib\site-packages (from requests->folium) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jdaggett\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\jdaggett\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jdaggett\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Libraries imported!

# %% [markdown]
# ### San Francisco Covid19 Data <a name="Covid_Data"></a>

# %%
# Create URL to JSON file (alternatively this can be a filepath)
#url = 'https://data.sfgov.org/resource/tef6-3vsw.json'
url = 'https://data.sfgov.org/resource/tpyr-dvnc.json'
# Load the first sheet of the JSON file into a data frame
df = pd.read_json(url, orient='columns')

# View the first five rows
df.head()
covid_df = df.loc[df['area_type'] == 'Analysis Neighborhood']
covid_df.rename(columns={'id': 'Neighborhood', 'count': 'Cases','rate': 'Rate of Cases per 10k'}, inplace=True)
covid_df.head()
# Out:
#                 area_type                    Neighborhood  Cases  \
# 1   Analysis Neighborhood  Financial District/South Beach   79.0
# 2   Analysis Neighborhood                  Haight Ashbury   43.0
# 8   Analysis Neighborhood                  Outer Richmond   95.0
# 9   Analysis Neighborhood               Visitacion Valley  225.0
# 16  Analysis Neighborhood                    Lincoln Park    NaN
#
#     Rate of Cases per 10k  deaths  acs_population         last_updated_at  \
# 1               40.600267     0.0           19458 2020-07-21 15:00:16.553
# 2               23.213129     0.0           18524 2020-07-21 15:00:16.553
# 8               20.701227     NaN           45891 2020-07-21 15:00:16.553
# 9              118.389897     NaN           19005 2020-07-21 15:00:16.553
# 16                    NaN     NaN             305 2020-07-21 15:00:16.553
#
#                                          multipolygon
# 1   {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 2   {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 8   {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 9   {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 16  {'type': 'MultiPolygon', 'coordinates': [[[[-1...

# %%
covid_df['latitude'] = 0

# %%
covid_df['longitude'] = 0

# %%
address = "Lakeshore, San Francisco, CA"
geolocator = Nominatim(user_agent="SanFran_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

print('The geograpical coordinate of this city are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of this city are 42.3038299, -82.8189267.

# %%
covid_df.head()
# Out:
#                  area_type                    Neighborhood  Cases  \
# 1    Analysis Neighborhood  Financial District/South Beach   79.0
# 2    Analysis Neighborhood                  Haight Ashbury   43.0
# 8    Analysis Neighborhood                  Outer Richmond   95.0
# 9    Analysis Neighborhood               Visitacion Valley  225.0
# 16   Analysis Neighborhood                    Lincoln Park    NaN
# 22   Analysis Neighborhood                        Nob Hill   96.0
# 34   Analysis Neighborhood                       Glen Park   30.0
# 36   Analysis Neighborhood                  Bernal Heights  187.0
# 37   Analysis Neighborhood             Castro/Upper Market   66.0
# 38   Analysis Neighborhood                         Mission  810.0
# 39   Analysis Neighborhood                      Noe Valley   77.0
# 40   Analysis Neighborhood                   Outer Mission  217.0
# 41   Analysis Neighborhood                       Excelsior  410.0
# 42   Analysis Neighborhood                Golden Gate Park    NaN
# 43   Analysis Neighborhood                        Presidio   20.0
# 44   Analysis Neighborhood                    Inner Sunset   84.0
# 45   Analysis Neighborhood                 South of Market  208.0
# 46   Analysis Neighborhood                      Twin Peaks   38.0
# 47   Analysis Neighborhood                         Portola  138.0
# 48   Analysis Neighborhood              West of Twin Peaks   76.0
# 56   Analysis Neighborhood                        Seacliff    NaN
# 58   Analysis Neighborhood                  Inner Richmond   56.0
# 61   Analysis Neighborhood                    Hayes Valley   94.0
# 64   Analysis Neighborhood      Oceanview/Merced/Ingleside  174.0
# 86   Analysis Neighborhood                 Sunset/Parkside  145.0
# 100  Analysis Neighborhood                Western Addition  150.0
# 142  Analysis Neighborhood                    Potrero Hill  126.0
# 157  Analysis Neighborhood                     Mission Bay   63.0
# 175  Analysis Neighborhood                    McLaren Park    NaN
# 189  Analysis Neighborhood                       Chinatown   20.0
# 190  Analysis Neighborhood                 Pacific Heights   91.0
# 192  Analysis Neighborhood               Lone Mountain/USF   31.0
# 196  Analysis Neighborhood                      Tenderloin  445.0
# 229  Analysis Neighborhood                Presidio Heights   17.0
# 236  Analysis Neighborhood                    Russian Hill   55.0
# 237  Analysis Neighborhood           Bayview Hunters Point  705.0
# 238  Analysis Neighborhood                     North Beach   39.0
# 239  Analysis Neighborhood                          Marina  107.0
# 245  Analysis Neighborhood                       Japantown   42.0
# 258  Analysis Neighborhood                 Treasure Island   20.0
# 260  Analysis Neighborhood                       Lakeshore   44.0
#
#      Rate of Cases per 10k  deaths  acs_population         last_updated_at  \
# 1                40.600267     0.0           19458 2020-07-21 15:00:16.553
# 2                23.213129     0.0           18524 2020-07-21 15:00:16.553
# 8                20.701227     NaN           45891 2020-07-21 15:00:16.553
# 9               118.389897     NaN           19005 2020-07-21 15:00:16.553
# 16                     NaN     NaN             305 2020-07-21 15:00:16.553
# 22               36.118740     NaN           26579 2020-07-21 15:00:16.553
# 34               34.718204     NaN            8641 2020-07-21 15:00:16.553
# 36               72.318045     NaN           25858 2020-07-21 15:00:16.553
# 37               29.617663     0.0           22284 2020-07-21 15:00:16.553
# 38              135.817167     NaN           59639 2020-07-21 15:00:16.553
# 39               32.756200     NaN           23507 2020-07-21 15:00:16.553
# 40               87.313403     NaN           24853 2020-07-21 15:00:16.553
# 41              100.734626     NaN           40701 2020-07-21 15:00:16.553
# 42                     NaN     NaN              66 2020-07-21 15:00:16.553
# 43               48.555475     0.0            4119 2020-07-21 15:00:16.553
# 44               28.662094     NaN           29307 2020-07-21 15:00:16.553
# 45               95.539938     NaN           21771 2020-07-21 15:00:16.553
# 46               47.387455     0.0            8019 2020-07-21 15:00:16.553
# 47               83.318239     NaN           16563 2020-07-21 15:00:16.553
# 48               19.242455     NaN           39496 2020-07-21 15:00:16.553
# 56                     NaN     0.0            2490 2020-07-21 15:00:16.553
# 58               25.202520     NaN           22220 2020-07-21 15:00:16.553
# 61               47.769082     0.0           19678 2020-07-21 15:00:16.553
# 64               61.664954     NaN           28217 2020-07-21 15:00:16.553
# 86               17.594952     NaN           82410 2020-07-21 15:00:16.553
# 100              66.260270     NaN           22638 2020-07-21 15:00:16.553
# 142              88.676191     NaN           14209 2020-07-21 15:00:16.553
# 157              51.724138     0.0           12180 2020-07-21 15:00:16.553
# 175                    NaN     NaN             669 2020-07-21 15:00:16.553
# 189              13.571283     NaN           14737 2020-07-21 15:00:16.553
# 190              37.200556     NaN           24462 2020-07-21 15:00:16.553
# 192              17.385452     0.0           17831 2020-07-21 15:00:16.553
# 196             150.398810     NaN           29588 2020-07-21 15:00:16.553
# 229                    NaN     0.0           10699 2020-07-21 15:00:16.553
# 236              30.846887     NaN           17830 2020-07-21 15:00:16.553
# 237             188.532920     NaN           37394 2020-07-21 15:00:16.553
# 238              33.516672     NaN           11636 2020-07-21 15:00:16.553
# 239              42.240733     0.0           25331 2020-07-21 15:00:16.553
# 245             118.912797     0.0            3532 2020-07-21 15:00:16.553
# 258              65.274151     0.0            3064 2020-07-21 15:00:16.553
# 260              30.048487     0.0           14643 2020-07-21 15:00:16.553
#
#                                           multipolygon   latitude   longitude
# 1    {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.793647 -122.398938
# 2    {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.770015 -122.446952
# 8    {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.777046 -122.465453
# 9    {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.712132 -122.409713
# 16   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.784625 -122.499086
# 22   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.793262 -122.415249
# 34   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.734281 -122.434470
# 36   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.742986 -122.415804
# 37   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.760856 -122.434957
# 38   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  49.158935 -122.283583
# 39   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.751591 -122.432081
# 40   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.752498 -122.412826
# 41   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.721794 -122.435382
# 42   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 43   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 44   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 45   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 46   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 47   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 48   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 56   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 58   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 61   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 64   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 86   {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 100  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 142  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 157  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 175  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 189  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 190  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 192  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 196  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 229  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 236  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 237  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 238  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 239  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 245  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 258  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000
# 260  {'type': 'MultiPolygon', 'coordinates': [[[[-1...   0.000000    0.000000

# %%
nbr = 'McLaren Park'
latitude = 37.7180842
longitude = -122.4190721
covid_df.loc[covid_df['Neighborhood'] == nbr, 'latitude'] = latitude
covid_df.loc[covid_df['Neighborhood'] == nbr, 'longitude'] = longitude

# %%
covid_df
# Out:
#                  area_type                    Neighborhood  Cases  \
# 1    Analysis Neighborhood  Financial District/South Beach   79.0
# 2    Analysis Neighborhood                  Haight Ashbury   43.0
# 8    Analysis Neighborhood                  Outer Richmond   95.0
# 9    Analysis Neighborhood               Visitacion Valley  225.0
# 16   Analysis Neighborhood                    Lincoln Park    NaN
# 22   Analysis Neighborhood                        Nob Hill   96.0
# 34   Analysis Neighborhood                       Glen Park   30.0
# 36   Analysis Neighborhood                  Bernal Heights  187.0
# 37   Analysis Neighborhood             Castro/Upper Market   66.0
# 38   Analysis Neighborhood                         Mission  810.0
# 39   Analysis Neighborhood                      Noe Valley   77.0
# 40   Analysis Neighborhood                   Outer Mission  217.0
# 41   Analysis Neighborhood                       Excelsior  410.0
# 42   Analysis Neighborhood                Golden Gate Park    NaN
# 43   Analysis Neighborhood                        Presidio   20.0
# 44   Analysis Neighborhood                    Inner Sunset   84.0
# 45   Analysis Neighborhood                 South of Market  208.0
# 46   Analysis Neighborhood                      Twin Peaks   38.0
# 47   Analysis Neighborhood                         Portola  138.0
# 48   Analysis Neighborhood              West of Twin Peaks   76.0
# 56   Analysis Neighborhood                        Seacliff    NaN
# 58   Analysis Neighborhood                  Inner Richmond   56.0
# 61   Analysis Neighborhood                    Hayes Valley   94.0
# 64   Analysis Neighborhood      Oceanview/Merced/Ingleside  174.0
# 86   Analysis Neighborhood                 Sunset/Parkside  145.0
# 100  Analysis Neighborhood                Western Addition  150.0
# 142  Analysis Neighborhood                    Potrero Hill  126.0
# 157  Analysis Neighborhood                     Mission Bay   63.0
# 175  Analysis Neighborhood                    McLaren Park    NaN
# 189  Analysis Neighborhood                       Chinatown   20.0
# 190  Analysis Neighborhood                 Pacific Heights   91.0
# 192  Analysis Neighborhood               Lone Mountain/USF   31.0
# 196  Analysis Neighborhood                      Tenderloin  445.0
# 229  Analysis Neighborhood                Presidio Heights   17.0
# 236  Analysis Neighborhood                    Russian Hill   55.0
# 237  Analysis Neighborhood           Bayview Hunters Point  705.0
# 238  Analysis Neighborhood                     North Beach   39.0
# 239  Analysis Neighborhood                          Marina  107.0
# 245  Analysis Neighborhood                       Japantown   42.0
# 258  Analysis Neighborhood                 Treasure Island   20.0
# 260  Analysis Neighborhood                       Lakeshore   44.0
#
#      Rate of Cases per 10k  deaths  acs_population         last_updated_at  \
# 1                40.600267     0.0           19458 2020-07-21 15:00:16.553
# 2                23.213129     0.0           18524 2020-07-21 15:00:16.553
# 8                20.701227     NaN           45891 2020-07-21 15:00:16.553
# 9               118.389897     NaN           19005 2020-07-21 15:00:16.553
# 16                     NaN     NaN             305 2020-07-21 15:00:16.553
# 22               36.118740     NaN           26579 2020-07-21 15:00:16.553
# 34               34.718204     NaN            8641 2020-07-21 15:00:16.553
# 36               72.318045     NaN           25858 2020-07-21 15:00:16.553
# 37               29.617663     0.0           22284 2020-07-21 15:00:16.553
# 38              135.817167     NaN           59639 2020-07-21 15:00:16.553
# 39               32.756200     NaN           23507 2020-07-21 15:00:16.553
# 40               87.313403     NaN           24853 2020-07-21 15:00:16.553
# 41              100.734626     NaN           40701 2020-07-21 15:00:16.553
# 42                     NaN     NaN              66 2020-07-21 15:00:16.553
# 43               48.555475     0.0            4119 2020-07-21 15:00:16.553
# 44               28.662094     NaN           29307 2020-07-21 15:00:16.553
# 45               95.539938     NaN           21771 2020-07-21 15:00:16.553
# 46               47.387455     0.0            8019 2020-07-21 15:00:16.553
# 47               83.318239     NaN           16563 2020-07-21 15:00:16.553
# 48               19.242455     NaN           39496 2020-07-21 15:00:16.553
# 56                     NaN     0.0            2490 2020-07-21 15:00:16.553
# 58               25.202520     NaN           22220 2020-07-21 15:00:16.553
# 61               47.769082     0.0           19678 2020-07-21 15:00:16.553
# 64               61.664954     NaN           28217 2020-07-21 15:00:16.553
# 86               17.594952     NaN           82410 2020-07-21 15:00:16.553
# 100              66.260270     NaN           22638 2020-07-21 15:00:16.553
# 142              88.676191     NaN           14209 2020-07-21 15:00:16.553
# 157              51.724138     0.0           12180 2020-07-21 15:00:16.553
# 175                    NaN     NaN             669 2020-07-21 15:00:16.553
# 189              13.571283     NaN           14737 2020-07-21 15:00:16.553
# 190              37.200556     NaN           24462 2020-07-21 15:00:16.553
# 192              17.385452     0.0           17831 2020-07-21 15:00:16.553
# 196             150.398810     NaN           29588 2020-07-21 15:00:16.553
# 229                    NaN     0.0           10699 2020-07-21 15:00:16.553
# 236              30.846887     NaN           17830 2020-07-21 15:00:16.553
# 237             188.532920     NaN           37394 2020-07-21 15:00:16.553
# 238              33.516672     NaN           11636 2020-07-21 15:00:16.553
# 239              42.240733     0.0           25331 2020-07-21 15:00:16.553
# 245             118.912797     0.0            3532 2020-07-21 15:00:16.553
# 258              65.274151     0.0            3064 2020-07-21 15:00:16.553
# 260              30.048487     0.0           14643 2020-07-21 15:00:16.553
#
#                                           multipolygon   latitude   longitude
# 1    {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.793647 -122.398938
# 2    {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.770015 -122.446952
# 8    {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.777046 -122.465453
# 9    {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.712132 -122.409713
# 16   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.784625 -122.499086
# 22   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.793262 -122.415249
# 34   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.734281 -122.434470
# 36   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.742986 -122.415804
# 37   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.760856 -122.434957
# 38   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.760000 -122.420000
# 39   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.751591 -122.432081
# 40   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.752498 -122.412826
# 41   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.721794 -122.435382
# 42   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.769368 -122.482184
# 43   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.798746 -122.464589
# 44   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.761450 -122.467643
# 45   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.780893 -122.400952
# 46   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.754640 -122.446480
# 47   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.726379 -122.408551
# 48   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.748000 -122.463000
# 56   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.788541 -122.486916
# 58   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.770917 -122.479249
# 61   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.776685 -122.422936
# 64   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.713651 -122.457483
# 86   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.750000 -122.490000
# 100  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.779559 -122.429810
# 142  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.756583 -122.399137
# 157  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.770774 -122.391171
# 175  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.718084 -122.419072
# 189  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.794301 -122.406376
# 190  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.792717 -122.435644
# 192  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.779096 -122.451916
# 196  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.784249 -122.413993
# 229  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.788751 -122.453027
# 236  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.800073 -122.417094
# 237  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.726870 -122.388730
# 238  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.801175 -122.409002
# 239  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.803000 -122.436000
# 245  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.785579 -122.429809
# 258  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.823354 -122.370153
# 260  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.733611 -122.491389

# %%
covid_df.head()
# Out:
#                 area_type                    Neighborhood  Cases  \
# 1   Analysis Neighborhood  Financial District/South Beach   79.0
# 2   Analysis Neighborhood                  Haight Ashbury   43.0
# 8   Analysis Neighborhood                  Outer Richmond   95.0
# 9   Analysis Neighborhood               Visitacion Valley  225.0
# 16  Analysis Neighborhood                    Lincoln Park    NaN
#
#     Rate of Cases per 10k  deaths  acs_population         last_updated_at  \
# 1               40.600267     0.0           19458 2020-07-21 15:00:16.553
# 2               23.213129     0.0           18524 2020-07-21 15:00:16.553
# 8               20.701227     NaN           45891 2020-07-21 15:00:16.553
# 9              118.389897     NaN           19005 2020-07-21 15:00:16.553
# 16                    NaN     NaN             305 2020-07-21 15:00:16.553
#
#                                          multipolygon   latitude   longitude
# 1   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.793647 -122.398938
# 2   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.770015 -122.446952
# 8   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.777046 -122.465453
# 9   {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.712132 -122.409713
# 16  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.784625 -122.499086

# %%
# Base San Francisco Map
address = "San Francisco, CA"
geolocator = Nominatim(user_agent="SanFran_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
# San Francisco latitude and longitude values
latitude = 37.77
longitude = -122.42

print('The geograpical coordinate of this city are {}, {}.'.format(latitude, longitude))
map_SF = folium.Map(location=[latitude, longitude], zoom_start=12)
map_SF
# Out:
# The geograpical coordinate of this city are 37.77, -122.42.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### San Francisco Health Inspection Data <a name="SF_Data"></a>

# %%
# Create URL to JSON file (alternatively this can be a filepath)
url = 'https://data.sfgov.org/resource/pyih-qa8i.json'

# Load the first sheet of the JSON file into a data frame
health_df = pd.read_json(url, orient='columns')
health_df['business_name'].str.strip()
# View the first five rows
health_df.head()
# Out:
#    business_id            business_name  business_address  business_city  \
# 0        69618  Fancy Wheatfield Bakery  1362 Stockton St  San Francisco
# 1        97975               BREADBELLY   1408 Clement St  San Francisco
# 2        69487   Hakkasan San Francisco       1 Kearny St  San Francisco
# 3        91044    Chopsticks Restaurant   4615 Mission St  San Francisco
# 4        85987                  Tselogs      552 Jones St  San Francisco
#
#   business_state business_postal_code  inspection_id          inspection_date  \
# 0             CA                94133  6961820190304  2019-03-04T00:00:00.000
# 1             CA                94118  9797520190725  2019-07-25T00:00:00.000
# 2             CA                94108  6948720180418  2018-04-18T00:00:00.000
# 3             CA                94112  9104420170818  2017-08-18T00:00:00.000
# 4             CA                94102  8598720180412  2018-04-12T00:00:00.000
#
#              inspection_type  violation_id  ... inspection_score  \
# 0                  Complaint  6.961820e+18  ...              NaN
# 1      Routine - Unscheduled  9.797520e+18  ...             96.0
# 2      Routine - Unscheduled  6.948720e+18  ...             88.0
# 3  Non-inspection site visit           NaN  ...              NaN
# 4      Routine - Unscheduled  8.598720e+18  ...             94.0
#
#   business_latitude  business_longitude  business_location  \
# 0               NaN                 NaN                NaN
# 1               NaN                 NaN                NaN
# 2               NaN                 NaN                NaN
# 3               NaN                 NaN                NaN
# 4               NaN                 NaN                NaN
#
#    :@computed_region_fyvs_ahh9  :@computed_region_p5aj_wyqh  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   :@computed_region_rxqg_mtj9  :@computed_region_yftq_j783  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    :@computed_region_bh8s_q3mv  :@computed_region_ajp5_b2md
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
# [5 rows x 23 columns]

# %%
# Only work with Restaurants with an inspection score
health_df = health_df[health_df['inspection_score'].notnull()]
health_df.sort_values(by='inspection_score', ascending=False)
# Out:
#      business_id            business_name  \
# 141        93193           Ballast Coffee
# 160        90010                  Noeteca
# 407        95129      Homeplate Boba Cart
# 781        94935     94635 Baby Bull Cart
# 247        86381             The Saratoga
# ..           ...                      ...
# 888        71008        House of Pancakes
# 136        90622          Taqueria Lolita
# 890        91843  Hello Sandwich & Noodle
# 707         1154     SUNFLOWER RESTAURANT
# 561         1154     SUNFLOWER RESTAURANT
#
#                               business_address  business_city business_state  \
# 141                        329 West Portal Ave  San Francisco             CA
# 160                            1551 Dolores St  San Francisco             CA
# 407  24 Willie Mays Pl View Level, Section 319  San Francisco             CA
# 781         24 Willie Mays Pl Upper CF Sec 143  San Francisco             CA
# 247                             1000 Larkin St  San Francisco             CA
# ..                                         ...            ...            ...
# 888                                937 TARAVAL  San Francisco             CA
# 136                              750 Phelps St  San Francisco             CA
# 890                              426 Larkin St  San Francisco             CA
# 707                            506 Valencia St  San Francisco             CA
# 561                            506 Valencia St  San Francisco             CA
#
#     business_postal_code  inspection_id          inspection_date  \
# 141                94127  9319320181101  2018-11-01T00:00:00.000
# 160                94110  9001020190729  2019-07-29T00:00:00.000
# 407                94107  9512920180911  2018-09-11T00:00:00.000
# 781                94107  9493520190412  2019-04-12T00:00:00.000
# 247                94109  8638120190822  2019-08-22T00:00:00.000
# ..                   ...            ...                      ...
# 888                94116  7100820190820  2019-08-20T00:00:00.000
# 136                94124  9062220180821  2018-08-21T00:00:00.000
# 890                94102  9184320180822  2018-08-22T00:00:00.000
# 707                94103   115420190327  2019-03-27T00:00:00.000
# 561                94103   115420190327  2019-03-27T00:00:00.000
#
#            inspection_type  violation_id  ... inspection_score  \
# 141  Routine - Unscheduled           NaN  ...            100.0
# 160  Routine - Unscheduled           NaN  ...            100.0
# 407  Routine - Unscheduled           NaN  ...            100.0
# 781  Routine - Unscheduled           NaN  ...            100.0
# 247  Routine - Unscheduled           NaN  ...            100.0
# ..                     ...           ...  ...              ...
# 888  Routine - Unscheduled  7.100820e+18  ...             59.0
# 136  Routine - Unscheduled  9.062220e+18  ...             57.0
# 890  Routine - Unscheduled  9.184320e+18  ...             55.0
# 707  Routine - Unscheduled  1.154202e+17  ...             46.0
# 561  Routine - Unscheduled  1.154202e+17  ...             46.0
#
#     business_latitude  business_longitude  \
# 141               NaN                 NaN
# 160               NaN                 NaN
# 407               NaN                 NaN
# 781               NaN                 NaN
# 247               NaN                 NaN
# ..                ...                 ...
# 888               NaN                 NaN
# 136               NaN                 NaN
# 890               NaN                 NaN
# 707         37.764678         -122.421905
# 561         37.764678         -122.421905
#
#                                      business_location  \
# 141                                                NaN
# 160                                                NaN
# 407                                                NaN
# 781                                                NaN
# 247                                                NaN
# ..                                                 ...
# 888                                                NaN
# 136                                                NaN
# 890                                                NaN
# 707  {'type': 'Point', 'coordinates': [-122.421905,...
# 561  {'type': 'Point', 'coordinates': [-122.421905,...
#
#      :@computed_region_fyvs_ahh9  :@computed_region_p5aj_wyqh  \
# 141                          NaN                          NaN
# 160                          NaN                          NaN
# 407                          NaN                          NaN
# 781                          NaN                          NaN
# 247                          NaN                          NaN
# ..                           ...                          ...
# 888                          NaN                          NaN
# 136                          NaN                          NaN
# 890                          NaN                          NaN
# 707                         19.0                          4.0
# 561                         19.0                          4.0
#
#     :@computed_region_rxqg_mtj9  :@computed_region_yftq_j783  \
# 141                         NaN                          NaN
# 160                         NaN                          NaN
# 407                         NaN                          NaN
# 781                         NaN                          NaN
# 247                         NaN                          NaN
# ..                          ...                          ...
# 888                         NaN                          NaN
# 136                         NaN                          NaN
# 890                         NaN                          NaN
# 707                         5.0                          8.0
# 561                         5.0                          8.0
#
#      :@computed_region_bh8s_q3mv  :@computed_region_ajp5_b2md
# 141                          NaN                          NaN
# 160                          NaN                          NaN
# 407                          NaN                          NaN
# 781                          NaN                          NaN
# 247                          NaN                          NaN
# ..                           ...                          ...
# 888                          NaN                          NaN
# 136                          NaN                          NaN
# 890                          NaN                          NaN
# 707                      28859.0                         20.0
# 561                      28859.0                         20.0
#
# [524 rows x 23 columns]

# %%
#Remove duplicates
health_df = health_df.drop_duplicates(subset='business_id', keep="first")
health_df.shape
# Out:
# (408, 23)

# %%
# df['risk_category'].value_counts()
health_df['inspection_score'].describe()
# Out:
# count    408.000000
# mean      87.473039
# std        8.921677
# min       46.000000
# 25%       82.000000
# 50%       88.000000
# 75%       94.000000
# max      100.000000
# Name: inspection_score, dtype: float64

# %% [markdown]
# #### 408 Businesses Inspections Scores range between 46 and 100

# %%
health_df.head()
# Out:
#    business_id            business_name business_address  business_city business_state business_postal_code  inspection_id          inspection_date        inspection_type  violation_id                                    violation_description  risk_category  business_phone_number  inspection_score  business_latitude  business_longitude business_location  :@computed_region_fyvs_ahh9  :@computed_region_p5aj_wyqh  :@computed_region_rxqg_mtj9  :@computed_region_yftq_j783  :@computed_region_bh8s_q3mv  :@computed_region_ajp5_b2md
# 1        97975               BREADBELLY  1408 Clement St  San Francisco             CA                94118  9797520190725  2019-07-25T00:00:00.000  Routine - Unscheduled  9.797520e+18  Inadequately cleaned or sanitized food contact surfaces  Moderate Risk           1.415724e+10              96.0                NaN                 NaN               NaN                          NaN                          NaN                          NaN                          NaN                          NaN                          NaN
# 2        69487   Hakkasan San Francisco      1 Kearny St  San Francisco             CA                94108  6948720180418  2018-04-18T00:00:00.000  Routine - Unscheduled  6.948720e+18       Inadequate and inaccessible handwashing facilities  Moderate Risk                    NaN              88.0                NaN                 NaN               NaN                          NaN                          NaN                          NaN                          NaN                          NaN                          NaN
# 4        85987                  Tselogs     552 Jones St  San Francisco             CA                94102  8598720180412  2018-04-12T00:00:00.000  Routine - Unscheduled  8.598720e+18                                 Improper thawing methods  Moderate Risk                    NaN              94.0                NaN                 NaN               NaN                          NaN                          NaN                          NaN                          NaN                          NaN                          NaN
# 8        77901  The Estate Kitchen, LLC    799 Bryant St  San Francisco             CA                94107  7790120180416  2018-04-16T00:00:00.000  Routine - Unscheduled  7.790120e+18                                    Improper food storage       Low Risk                    NaN              86.0                NaN                 NaN               NaN                          NaN                          NaN                          NaN                          NaN                          NaN                          NaN
# 9        87782             Beloved Cafe     3338 24th St  San Francisco             CA                94110  8778220180502  2018-05-02T00:00:00.000  Routine - Unscheduled  8.778220e+18                              Low risk vermin infestation       Low Risk           1.415554e+10              96.0                NaN                 NaN               NaN                          NaN                          NaN                          NaN                          NaN                          NaN                          NaN

# %%
def get_geocode(address):
    LatLong = []
    address = address + ', San Francisco, CA'
    geolocator = Nominatim(user_agent="SF_explorer")
    location = geolocator.geocode(address)
    if location is None:
        latitude = 0
        longitude = 0
    else:
        latitude = location.latitude
        longitude = location.longitude
    
    return latitude, longitude

# %%
health_df.head()
# Out:
#   business_id            business_name business_address  business_city business_state business_postal_code  inspection_id          inspection_date        inspection_type violation_id                                    violation_description  risk_category business_phone_number inspection_score business_latitude business_longitude business_location :@computed_region_fyvs_ahh9 :@computed_region_p5aj_wyqh :@computed_region_rxqg_mtj9 :@computed_region_yftq_j783 :@computed_region_bh8s_q3mv :@computed_region_ajp5_b2md
# 1       97975               BREADBELLY  1408 Clement St  San Francisco             CA                94118  9797520190725  2019-07-25T00:00:00.000  Routine - Unscheduled  9.79752e+18  Inadequately cleaned or sanitized food contact surfaces  Moderate Risk           1.41572e+10               96               NaN                NaN               NaN                         NaN                         NaN                         NaN                         NaN                         NaN                         NaN
# 2       69487   Hakkasan San Francisco      1 Kearny St  San Francisco             CA                94108  6948720180418  2018-04-18T00:00:00.000  Routine - Unscheduled  6.94872e+18       Inadequate and inaccessible handwashing facilities  Moderate Risk                   NaN               88               NaN                NaN               NaN                         NaN                         NaN                         NaN                         NaN                         NaN                         NaN
# 4       85987                  Tselogs     552 Jones St  San Francisco             CA                94102  8598720180412  2018-04-12T00:00:00.000  Routine - Unscheduled  8.59872e+18                                 Improper thawing methods  Moderate Risk                   NaN               94               NaN                NaN               NaN                         NaN                         NaN                         NaN                         NaN                         NaN                         NaN
# 8       77901  The Estate Kitchen, LLC    799 Bryant St  San Francisco             CA                94107  7790120180416  2018-04-16T00:00:00.000  Routine - Unscheduled  7.79012e+18                                    Improper food storage       Low Risk                   NaN               86               NaN                NaN               NaN                         NaN                         NaN                         NaN                         NaN                         NaN                         NaN
# 9       87782             Beloved Cafe     3338 24th St  San Francisco             CA                94110  8778220180502  2018-05-02T00:00:00.000  Routine - Unscheduled  8.77822e+18                              Low risk vermin infestation       Low Risk           1.41555e+10               96               NaN                NaN               NaN                         NaN                         NaN                         NaN                         NaN                         NaN                         NaN

# %%
#Populate Coordinates
for index, row in health_df.iterrows():
    lat, lng = get_geocode(row['business_address'])
    row['business_longitude'] = lng
    row['business_latitude'] = lat

# %%
health_df.head()
# Out:
#    business_id            business_name business_address  business_city  \
# 1        97975               BREADBELLY  1408 Clement St  San Francisco
# 2        69487   Hakkasan San Francisco      1 Kearny St  San Francisco
# 4        85987                  Tselogs     552 Jones St  San Francisco
# 8        77901  The Estate Kitchen, LLC    799 Bryant St  San Francisco
# 9        87782             Beloved Cafe     3338 24th St  San Francisco
#
#   business_state business_postal_code  inspection_id          inspection_date  \
# 1             CA                94118  9797520190725  2019-07-25T00:00:00.000
# 2             CA                94108  6948720180418  2018-04-18T00:00:00.000
# 4             CA                94102  8598720180412  2018-04-12T00:00:00.000
# 8             CA                94107  7790120180416  2018-04-16T00:00:00.000
# 9             CA                94110  8778220180502  2018-05-02T00:00:00.000
#
#          inspection_type  violation_id  ... inspection_score  \
# 1  Routine - Unscheduled  9.797520e+18  ...             96.0
# 2  Routine - Unscheduled  6.948720e+18  ...             88.0
# 4  Routine - Unscheduled  8.598720e+18  ...             94.0
# 8  Routine - Unscheduled  7.790120e+18  ...             86.0
# 9  Routine - Unscheduled  8.778220e+18  ...             96.0
#
#   business_latitude  business_longitude  business_location  \
# 1               NaN                 NaN                NaN
# 2               NaN                 NaN                NaN
# 4               NaN                 NaN                NaN
# 8               NaN                 NaN                NaN
# 9               NaN                 NaN                NaN
#
#    :@computed_region_fyvs_ahh9  :@computed_region_p5aj_wyqh  \
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 4                          NaN                          NaN
# 8                          NaN                          NaN
# 9                          NaN                          NaN
#
#   :@computed_region_rxqg_mtj9  :@computed_region_yftq_j783  \
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 4                         NaN                          NaN
# 8                         NaN                          NaN
# 9                         NaN                          NaN
#
#    :@computed_region_bh8s_q3mv  :@computed_region_ajp5_b2md
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 4                          NaN                          NaN
# 8                          NaN                          NaN
# 9                          NaN                          NaN
#
# [5 rows x 23 columns]

# %%
health_df = health_df[health_df['business_latitude'] != 0]
health_df
# Out:
#      business_id                                      business_name  \
# 1          97975                                         BREADBELLY
# 2          69487                             Hakkasan San Francisco
# 4          85987                                            Tselogs
# 8          77901                            The Estate Kitchen, LLC
# 9          87782                                       Beloved Cafe
# ..           ...                                                ...
# 989         1671                             Just For You Cafe Inc.
# 992         1269                                          STARBUCKS
# 995        95311  95311 C&C Concessions/Portable 130 Lemonade Sn...
# 998        94910                                      Ike's Kitchen
# 999        86404                               Fresh & Natural Cafe
#
#                              business_address  business_city business_state  \
# 1                             1408 Clement St  San Francisco             CA
# 2                                 1 Kearny St  San Francisco             CA
# 4                                552 Jones St  San Francisco             CA
# 8                               799 Bryant St  San Francisco             CA
# 9                                3338 24th St  San Francisco             CA
# ..                                        ...            ...            ...
# 989                               732 22ND St  San Francisco             CA
# 992                              201 SPEAR St  San Francisco             CA
# 995  24 Willie Mays Pl Promenade Lvl Sect 130  San Francisco             CA
# 998                          800 Van Ness Ave  San Francisco             CA
# 999                           2425 Geary Blvd  San Francisco             CA
#
#     business_postal_code  inspection_id          inspection_date  \
# 1                  94118  9797520190725  2019-07-25T00:00:00.000
# 2                  94108  6948720180418  2018-04-18T00:00:00.000
# 4                  94102  8598720180412  2018-04-12T00:00:00.000
# 8                  94107  7790120180416  2018-04-16T00:00:00.000
# 9                  94110  8778220180502  2018-05-02T00:00:00.000
# ..                   ...            ...                      ...
# 989                94107   167120190624  2019-06-24T00:00:00.000
# 992                94105   126920190716  2019-07-16T00:00:00.000
# 995                94107  9531120190412  2019-04-12T00:00:00.000
# 998                94109  9491020180824  2018-08-24T00:00:00.000
# 999                94115  8640420180521  2018-05-21T00:00:00.000
#
#            inspection_type  violation_id  ... inspection_score  \
# 1    Routine - Unscheduled  9.797520e+18  ...             96.0
# 2    Routine - Unscheduled  6.948720e+18  ...             88.0
# 4    Routine - Unscheduled  8.598720e+18  ...             94.0
# 8    Routine - Unscheduled  7.790120e+18  ...             86.0
# 9    Routine - Unscheduled  8.778220e+18  ...             96.0
# ..                     ...           ...  ...              ...
# 989  Routine - Unscheduled  1.671202e+17  ...             92.0
# 992  Routine - Unscheduled  1.269202e+17  ...             94.0
# 995  Routine - Unscheduled           NaN  ...            100.0
# 998  Routine - Unscheduled  9.491020e+18  ...             77.0
# 999  Routine - Unscheduled  8.640420e+18  ...             96.0
#
#     business_latitude  business_longitude  \
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 4                 NaN                 NaN
# 8                 NaN                 NaN
# 9                 NaN                 NaN
# ..                ...                 ...
# 989         37.757948         -122.388862
# 992         37.790944         -122.392051
# 995               NaN                 NaN
# 998               NaN                 NaN
# 999               NaN                 NaN
#
#                                      business_location  \
# 1                                                  NaN
# 2                                                  NaN
# 4                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# ..                                                 ...
# 989  {'type': 'Point', 'coordinates': [-122.388862,...
# 992  {'type': 'Point', 'coordinates': [-122.392051,...
# 995                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#      :@computed_region_fyvs_ahh9  :@computed_region_p5aj_wyqh  \
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 4                            NaN                          NaN
# 8                            NaN                          NaN
# 9                            NaN                          NaN
# ..                           ...                          ...
# 989                         29.0                          3.0
# 992                          6.0                          2.0
# 995                          NaN                          NaN
# 998                          NaN                          NaN
# 999                          NaN                          NaN
#
#     :@computed_region_rxqg_mtj9  :@computed_region_yftq_j783  \
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 4                           NaN                          NaN
# 8                           NaN                          NaN
# 9                           NaN                          NaN
# ..                          ...                          ...
# 989                         8.0                         10.0
# 992                         9.0                          6.0
# 995                         NaN                          NaN
# 998                         NaN                          NaN
# 999                         NaN                          NaN
#
#      :@computed_region_bh8s_q3mv  :@computed_region_ajp5_b2md
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 4                            NaN                          NaN
# 8                            NaN                          NaN
# 9                            NaN                          NaN
# ..                           ...                          ...
# 989                      28856.0                         26.0
# 992                      28855.0                          8.0
# 995                          NaN                          NaN
# 998                          NaN                          NaN
# 999                          NaN                          NaN
#
# [408 rows x 23 columns]

# %% [markdown]
# ### Foursquare API Data <a name="FourSquare"></a>

# %%
CLIENT_ID = '0KAOUTNBE0UZIMJ0UVOCAWXBISWMGOZ0GRBX53GERNC4GOZR' 
CLIENT_SECRET = 'RMRTIYEFM4QRTZMFDAUZGAAXVZVCTHYR2ULOKXIRO4HHSI5D' 
VERSION = '20200707'
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
radius=4000 #4 km
LIMIT=100
# Out:
# Your credentials:
# CLIENT_ID: 0KAOUTNBE0UZIMJ0UVOCAWXBISWMGOZ0GRBX53GERNC4GOZR
# CLIENT_SECRET:RMRTIYEFM4QRTZMFDAUZGAAXVZVCTHYR2ULOKXIRO4HHSI5D

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=400):
    venues_list=[]
    LIMIT = 100
    for name, lat, lng in zip(names, latitudes, longitudes):
          # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
          # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng,
            v['venue']['id'],
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
        
        nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue ID',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
SF_venues = getNearbyVenues(names=covid_df['Neighborhood'], 
                                    latitudes=covid_df['latitude'], 
                                    longitudes=covid_df['longitude'])
SF_venues
# Out:
#                         Neighborhood  Neighborhood Latitude  \
# 0     Financial District/South Beach              37.793647
# 1     Financial District/South Beach              37.793647
# 2     Financial District/South Beach              37.793647
# 3     Financial District/South Beach              37.793647
# 4     Financial District/South Beach              37.793647
# ...                              ...                    ...
# 1418                       Lakeshore              37.733611
# 1419                       Lakeshore              37.733611
# 1420                       Lakeshore              37.733611
# 1421                       Lakeshore              37.733611
# 1422                       Lakeshore              37.733611
#
#       Neighborhood Longitude                  Venue ID  \
# 0                -122.398938  40c10d00f964a520df001fe3
# 1                -122.398938  587449b8abf6322f4435759f
# 2                -122.398938  51acf1382fc674aef7a09b1a
# 3                -122.398938  4bf2e4376a31d13ac307942e
# 4                -122.398938  459b7818f964a52089401fe3
# ...                      ...                       ...
# 1418             -122.491389  4af730b2f964a520fb0622e3
# 1419             -122.491389  4b7a016cf964a520b61e2fe3
# 1420             -122.491389  4a809dc6f964a520b6f51fe3
# 1421             -122.491389  54710b85498e6ff092294183
# 1422             -122.491389  5eefe7625488620008839d06
#
#                           Venue  Venue Latitude  Venue Longitude  \
# 0     Embarcadero Center Cinema       37.794871      -122.399648
# 1                     Homegrown       37.793617      -122.400000
# 2                   Wheel House       37.794481      -122.399970
# 3         Blue Hawaii Açaí Café       37.794668      -122.397912
# 4                      Perbacco       37.793288      -122.399134
# ...                         ...             ...              ...
# 1418       Big 5 Sporting Goods       37.732598      -122.490345
# 1419              Noah's Bagels       37.732443      -122.489940
# 1420                 YUYU Sushi       37.733055      -122.490703
# 1421                MassageLuXe       37.733346      -122.490851
# 1422                    Tea Hut       37.732480      -122.490555
#
#            Venue Category
# 0     Indie Movie Theater
# 1          Sandwich Place
# 2                     Gym
# 3              Acai House
# 4      Italian Restaurant
# ...                   ...
# 1418  Sporting Goods Shop
# 1419           Bagel Shop
# 1420     Sushi Restaurant
# 1421                  Spa
# 1422      Bubble Tea Shop
#
# [1423 rows x 8 columns]

# %%
SF_venues['Neighborhood'].value_counts()
# Out:
# Hayes Valley                      100
# Tenderloin                         92
# Chinatown                          92
# Castro/Upper Market                80
# Mission                            80
# Haight Ashbury                     76
# Outer Mission                      70
# Marina                             66
# North Beach                        65
# Japantown                          61
# South of Market                    55
# Financial District/South Beach     49
# Noe Valley                         48
# Mission Bay                        47
# Nob Hill                           43
# Inner Sunset                       38
# Glen Park                          37
# Excelsior                          36
# Pacific Heights                    33
# Presidio Heights                   25
# Russian Hill                       25
# Western Addition                   23
# Lakeshore                          23
# Lone Mountain/USF                  18
# Outer Richmond                     18
# West of Twin Peaks                 14
# Golden Gate Park                   13
# Potrero Hill                       11
# Inner Richmond                     11
# Sunset/Parkside                    10
# Lincoln Park                       10
# Treasure Island                     9
# Twin Peaks                          9
# Oceanview/Merced/Ingleside          8
# Bernal Heights                      7
# Bayview Hunters Point               6
# Presidio                            4
# Seacliff                            4
# McLaren Park                        3
# Portola                             3
# Visitacion Valley                   1
# Name: Neighborhood, dtype: int64

# %%
SF_venues['Venue Category'].value_counts()
#There are a lot of venues present that might not be present on Zomato so let's drop those
# Out:
# Coffee Shop           68
# Park                  46
# Bakery                31
# Café                  30
# Mexican Restaurant    30
#                       ..
# Nabe Restaurant        1
# Persian Restaurant     1
# Tattoo Parlor          1
# Skating Rink           1
# Acai House             1
# Name: Venue Category, Length: 272, dtype: int64

# %%
SF_venues=SF_venues[SF_venues['Venue Category'].isin(['Pizza Place','Italian Restaurant'])]
SF_venues.head()
# Out:
#                        Neighborhood  Neighborhood Latitude  \
# 4    Financial District/South Beach              37.793647
# 59                   Haight Ashbury              37.770015
# 103                  Haight Ashbury              37.770015
# 121                  Haight Ashbury              37.770015
# 137                  Outer Richmond              37.777046
#
#      Neighborhood Longitude                  Venue ID  \
# 4               -122.398938  459b7818f964a52089401fe3
# 59              -122.446952  5849c58a6ad73d598e7f4174
# 103             -122.446952  44786832f964a520ca331fe3
# 121             -122.446952  4b6cec46f964a5201a5e2ce3
# 137             -122.465453  5463e257498e84f8746a0d9d
#
#                              Venue  Venue Latitude  Venue Longitude  \
# 4                         Perbacco       37.793288      -122.399134
# 59   Slice House by Tony Gemignani       37.769832      -122.447570
# 103     Escape From New York Pizza       37.769416      -122.451361
# 121                  cookwithjames       37.767981      -122.445134
# 137              Grinders Pizzeria       37.777373      -122.463710
#
#          Venue Category
# 4    Italian Restaurant
# 59          Pizza Place
# 103         Pizza Place
# 121  Italian Restaurant
# 137         Pizza Place

# %%
SF_venues.shape
# Out:
# (56, 8)

# %%
SF_venues['rating'] = ""

# %%
SF_venues.head()
# Out:
#                        Neighborhood  Neighborhood Latitude  \
# 4    Financial District/South Beach              37.793647
# 59                   Haight Ashbury              37.770015
# 103                  Haight Ashbury              37.770015
# 121                  Haight Ashbury              37.770015
# 137                  Outer Richmond              37.777046
#
#      Neighborhood Longitude                  Venue ID  \
# 4               -122.398938  459b7818f964a52089401fe3
# 59              -122.446952  5849c58a6ad73d598e7f4174
# 103             -122.446952  44786832f964a520ca331fe3
# 121             -122.446952  4b6cec46f964a5201a5e2ce3
# 137             -122.465453  5463e257498e84f8746a0d9d
#
#                              Venue  Venue Latitude  Venue Longitude  \
# 4                         Perbacco       37.793288      -122.399134
# 59   Slice House by Tony Gemignani       37.769832      -122.447570
# 103     Escape From New York Pizza       37.769416      -122.451361
# 121                  cookwithjames       37.767981      -122.445134
# 137              Grinders Pizzeria       37.777373      -122.463710
#
#          Venue Category rating
# 4    Italian Restaurant
# 59          Pizza Place
# 103         Pizza Place
# 121  Italian Restaurant
# 137         Pizza Place

# %%
# GET https://api.foursquare.com/v2/venues/VENUE_ID
venues_ids= SF_venues['Venue ID']
ratings=[]
for venue_id in venues_ids.values.tolist():
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    try:
        print(result['response']['venue']['rating'])
        # SF_venues.loc[SF_venues.rating == result['response']['venue']['rating'], "Venue ID"] = venue_id
        #ratings=ratings+[venues_rating]
    except:
        print('This venue has not been rated yet.')
#ratings

#venue_id = '4f3232e219836c91c7bfde94' # ID of Conca Cucina Italian Restaurant
#url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
# Out:
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.
# This venue has not been rated yet.

# %%
SF_Merged_df = pd.merge(SF_venues, covid_df, on='Neighborhood')

# %%
SF_Merged_df.head()
# Out:
#                      Neighborhood  Neighborhood Latitude  \
# 0  Financial District/South Beach              37.793647
# 1                  Haight Ashbury              37.770015
# 2                  Haight Ashbury              37.770015
# 3                  Haight Ashbury              37.770015
# 4                  Outer Richmond              37.777046
#
#    Neighborhood Longitude                  Venue ID  \
# 0             -122.398938  459b7818f964a52089401fe3
# 1             -122.446952  5849c58a6ad73d598e7f4174
# 2             -122.446952  44786832f964a520ca331fe3
# 3             -122.446952  4b6cec46f964a5201a5e2ce3
# 4             -122.465453  5463e257498e84f8746a0d9d
#
#                            Venue  Venue Latitude  Venue Longitude  \
# 0                       Perbacco       37.793288      -122.399134
# 1  Slice House by Tony Gemignani       37.769832      -122.447570
# 2     Escape From New York Pizza       37.769416      -122.451361
# 3                  cookwithjames       37.767981      -122.445134
# 4              Grinders Pizzeria       37.777373      -122.463710
#
#        Venue Category rating              area_type  Cases  \
# 0  Italian Restaurant         Analysis Neighborhood   79.0
# 1         Pizza Place         Analysis Neighborhood   43.0
# 2         Pizza Place         Analysis Neighborhood   43.0
# 3  Italian Restaurant         Analysis Neighborhood   43.0
# 4         Pizza Place         Analysis Neighborhood   95.0
#
#    Rate of Cases per 10k  deaths  acs_population         last_updated_at  \
# 0              40.600267     0.0           19458 2020-07-21 15:00:16.553
# 1              23.213129     0.0           18524 2020-07-21 15:00:16.553
# 2              23.213129     0.0           18524 2020-07-21 15:00:16.553
# 3              23.213129     0.0           18524 2020-07-21 15:00:16.553
# 4              20.701227     NaN           45891 2020-07-21 15:00:16.553
#
#                                         multipolygon   latitude   longitude
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.793647 -122.398938
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.770015 -122.446952
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.770015 -122.446952
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.770015 -122.446952
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  37.777046 -122.465453

# %%
SF_Merged_df.shape
# Out:
# (56, 18)

# %%
#health_df business_name

# %%
c_df = health_df.rename({'business_name': 'Venue'}, axis=1)

# %%
c_df.head()
# Out:
#    business_id                    Venue business_address  business_city  \
# 1        97975               BREADBELLY  1408 Clement St  San Francisco
# 2        69487   Hakkasan San Francisco      1 Kearny St  San Francisco
# 4        85987                  Tselogs     552 Jones St  San Francisco
# 8        77901  The Estate Kitchen, LLC    799 Bryant St  San Francisco
# 9        87782             Beloved Cafe     3338 24th St  San Francisco
#
#   business_state business_postal_code  inspection_id          inspection_date  \
# 1             CA                94118  9797520190725  2019-07-25T00:00:00.000
# 2             CA                94108  6948720180418  2018-04-18T00:00:00.000
# 4             CA                94102  8598720180412  2018-04-12T00:00:00.000
# 8             CA                94107  7790120180416  2018-04-16T00:00:00.000
# 9             CA                94110  8778220180502  2018-05-02T00:00:00.000
#
#          inspection_type  violation_id  ... inspection_score  \
# 1  Routine - Unscheduled  9.797520e+18  ...             96.0
# 2  Routine - Unscheduled  6.948720e+18  ...             88.0
# 4  Routine - Unscheduled  8.598720e+18  ...             94.0
# 8  Routine - Unscheduled  7.790120e+18  ...             86.0
# 9  Routine - Unscheduled  8.778220e+18  ...             96.0
#
#   business_latitude  business_longitude  business_location  \
# 1               NaN                 NaN                NaN
# 2               NaN                 NaN                NaN
# 4               NaN                 NaN                NaN
# 8               NaN                 NaN                NaN
# 9               NaN                 NaN                NaN
#
#    :@computed_region_fyvs_ahh9  :@computed_region_p5aj_wyqh  \
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 4                          NaN                          NaN
# 8                          NaN                          NaN
# 9                          NaN                          NaN
#
#   :@computed_region_rxqg_mtj9  :@computed_region_yftq_j783  \
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 4                         NaN                          NaN
# 8                         NaN                          NaN
# 9                         NaN                          NaN
#
#    :@computed_region_bh8s_q3mv  :@computed_region_ajp5_b2md
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 4                          NaN                          NaN
# 8                          NaN                          NaN
# 9                          NaN                          NaN
#
# [5 rows x 23 columns]

# %%
SF_Final_df = pd.merge(SF_Merged_df, c_df, on='Venue', how='outer')

# %%
SF_Final_df.head()
# Out:
#                      Neighborhood  Neighborhood Latitude  \
# 0  Financial District/South Beach              37.793647
# 1                  Haight Ashbury              37.770015
# 2                  Haight Ashbury              37.770015
# 3                  Haight Ashbury              37.770015
# 4                  Outer Richmond              37.777046
#
#    Neighborhood Longitude                  Venue ID  \
# 0             -122.398938  459b7818f964a52089401fe3
# 1             -122.446952  5849c58a6ad73d598e7f4174
# 2             -122.446952  44786832f964a520ca331fe3
# 3             -122.446952  4b6cec46f964a5201a5e2ce3
# 4             -122.465453  5463e257498e84f8746a0d9d
#
#                            Venue  Venue Latitude  Venue Longitude  \
# 0                       Perbacco       37.793288      -122.399134
# 1  Slice House by Tony Gemignani       37.769832      -122.447570
# 2     Escape From New York Pizza       37.769416      -122.451361
# 3                  cookwithjames       37.767981      -122.445134
# 4              Grinders Pizzeria       37.777373      -122.463710
#
#        Venue Category rating              area_type  ...  inspection_score  \
# 0  Italian Restaurant         Analysis Neighborhood  ...               NaN
# 1         Pizza Place         Analysis Neighborhood  ...               NaN
# 2         Pizza Place         Analysis Neighborhood  ...               NaN
# 3  Italian Restaurant         Analysis Neighborhood  ...               NaN
# 4         Pizza Place         Analysis Neighborhood  ...               NaN
#
#    business_latitude  business_longitude  business_location  \
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
#
#   :@computed_region_fyvs_ahh9 :@computed_region_p5aj_wyqh  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    :@computed_region_rxqg_mtj9  :@computed_region_yftq_j783  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    :@computed_region_bh8s_q3mv :@computed_region_ajp5_b2md
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
# [5 rows x 40 columns]
